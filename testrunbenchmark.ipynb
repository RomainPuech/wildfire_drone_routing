# %%
# Cell 1: Imports and Environment Setup

import sys
import os

# If your strategy or module paths aren't in sys.path already
sys.path.append("/Users/josephye/Desktop/wildfire_drone_routing/code")  # Update if necessary

# Optional: Check current working directory
os.getcwd()
# Out:
# '/Users/josephye/Desktop/wildfire_drone_routing'

# %%
# Cell 2: Imports from your existing modules

from benchmark import run_benchmark_for_strategy
from benchmark import build_custom_init_params, return_no_custom_parameters

# %%
# Cell 4: Define your strategy parameters

input_dir = "MinimalDataset/0001/Satellite_Images_Mask"  # Replace with your actual dataset path
strategy_folder = "code/strategy"            # Path to your strategies
sensor_strategy_file = "logged_sensor_placement.py"
sensor_class_name = "LoggedSensorPlacementStrategy"
drone_strategy_file = "logged_drone_routing.py"
drone_class_name = "LoggedDroneRoutingStrategy"

max_n_scenarii = 2
starting_time = 0
file_format = "jpg"  # or "jpg" if you're working with jpg scenarios

# %%
# Cell 5: Execute the benchmark function

run_benchmark_for_strategy(
    input_dir=input_dir,
    strategy_folder=strategy_folder,
    sensor_strategy_file=sensor_strategy_file,
    sensor_class_name=sensor_class_name,
    drone_strategy_file=drone_strategy_file,
    drone_class_name=drone_class_name,
    max_n_scenarii=max_n_scenarii,
    starting_time=starting_time,
    file_format=file_format,
    custom_init_params_fn= build_custom_init_params,
    custom_step_params_fn= return_no_custom_parameters
)
# Out:
# Looking for strategy file at: code/strategy/logged_sensor_placement.py
# Looking for strategy file at: code/strategy/logged_drone_routing.py
# [run_benchmark_for_strategy] Running sensor placement strategy...
# [LoggedSensorPlacementStrategy] Log file not found at MinimalDataset/0001/custom_params/layout_LoggedSensorPlacementStrategy_1_sensors.json. Running dummy optimization...
# [LoggedSensorPlacementStrategy] Dummy optimization done. Results saved to MinimalDataset/0001/custom_params/layout_LoggedSensorPlacementStrategy_1_sensors.json
# [LoggedDroneRoutingStrategy] Initialized with log file: MinimalDataset/0001/custom_params/layout_A.json
#   0%|          | 0/2 [00:00<?, ?it/s]
# Processing scenario MinimalDataset/0001/Satellite_Images_Mask/0001_00005
# [LoggedDroneRoutingStrategy] Log successfully written to MinimalDataset/0001/custom_params/layout_A.json
# [LoggedDroneRoutingStrategy] Calling dummy optimizer at timestep 0
# [Dummy Function] Generating dummy routing solution...
# ...
