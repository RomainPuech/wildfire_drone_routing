# %% [markdown]
# # Wildfire Hazard Potential for the United States (270-m), version 2023 (4th Edition)
#
# Dataset source: https://www.fs.usda.gov/rds/archive/products/RDS-2015-0047-4/_fileindex_RDS-2015-0047-4.html
#
# Documentation: https://firelab.org/sites/default/files/2024-02/whp2023_cls_conus_metadata.pdf
#
# https://data-usfs.hub.arcgis.com/datasets/usfs::wildfire-hazard-potential-version-2023-classified-image-service/explore?location=35.134247%2C-116.251988%2C6.95
#
# https://www.fs.usda.gov/rds/archive/catalog/RDS-2015-0047-4
#
#
# ## Data dictionary
#
# https://www.fs.usda.gov/rds/archive/products/RDS-2015-0047-4/_metadata_RDS-2015-0047-4.html

# %%
pip install rioxarray
# Out:
# Collecting rioxarray
#   Downloading rioxarray-0.19.0-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/wildfire/lib/python3.11/site-packages (from rioxarray) (24.2)
# Requirement already satisfied: rasterio>=1.4.3 in /opt/anaconda3/envs/wildfire/lib/python3.11/site-packages (from rioxarray) (1.4.3)
# Requirement already satisfied: xarray>=2024.7.0 in /opt/anaconda3/envs/wildfire/lib/python3.11/site-packages (from rioxarray) (2024.11.0)
# Requirement already satisfied: pyproj>=3.3 in /opt/anaconda3/envs/wildfire/lib/python3.11/site-packages (from rioxarray) (3.6.1)
# Requirement already satisfied: numpy>=1.23 in /opt/anaconda3/envs/wildfire/lib/python3.11/site-packages (from rioxarray) (1.26.4)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/wildfire/lib/python3.11/site-packages (from pyproj>=3.3->rioxarray) (2025.4.26)
# Requirement already satisfied: affine in /opt/anaconda3/envs/wildfire/lib/python3.11/site-packages (from rasterio>=1.4.3->rioxarray) (2.3.0)
# Requirement already satisfied: attrs in /opt/anaconda3/envs/wildfire/lib/python3.11/site-packages (from rasterio>=1.4.3->rioxarray) (24.3.0)
# Requirement already satisfied: click>=4.0 in /opt/anaconda3/envs/wildfire/lib/python3.11/site-packages (from rasterio>=1.4.3->rioxarray) (8.1.8)
# Requirement already satisfied: cligj>=0.5 in /opt/anaconda3/envs/wildfire/lib/python3.11/site-packages (from rasterio>=1.4.3->rioxarray) (0.7.2)
# Requirement already satisfied: click-plugins in /opt/anaconda3/envs/wildfire/lib/python3.11/site-packages (from rasterio>=1.4.3->rioxarray) (1.1.1)
# Requirement already satisfied: pyparsing in /opt/anaconda3/envs/wildfire/lib/python3.11/site-packages (from rasterio>=1.4.3->rioxarray) (3.2.0)
# Requirement already satisfied: pandas>=2.1 in /opt/anaconda3/envs/wildfire/lib/python3.11/site-packages (from xarray>=2024.7.0->rioxarray) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/wildfire/lib/python3.11/site-packages (from pandas>=2.1->xarray>=2024.7.0->rioxarray) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/wildfire/lib/python3.11/site-packages (from pandas>=2.1->xarray>=2024.7.0->rioxarray) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/wildfire/lib/python3.11/site-packages (from pandas>=2.1->xarray>=2024.7.0->rioxarray) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/wildfire/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=2.1->xarray>=2024.7.0->rioxarray) (1.17.0)
# Downloading rioxarray-0.19.0-py3-none-any.whl (62 kB)
# Installing collected packages: rioxarray
# Successfully installed rioxarray-0.19.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
import os
import random

from glob import glob

import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import rasterio
import rioxarray
import xarray as xr

from rasterio.enums import Resampling
from rasterio.errors import WindowError
from rasterio.features import geometry_mask
from rasterio.mask import mask
from rasterio.windows import Window

from shapely.geometry import Point, box

# %%
whp_filename = '../../WData/whp2023_GeoTIF/whp2023_cnt_conus.tif'

with rasterio.open(whp_filename) as src2:
    bounds = src2.bounds
    bbox = box(*bounds)
    geo = gpd.GeoDataFrame({'geometry': [bbox]}, crs=src2.crs)
    geo_json = [json.loads(geo.to_json())['features'][0]['geometry']]

print(len(geo_json))
# Out:
# 1

# %%
# Path to the folder containing .tif files
folder_path = "../../sim2real_layouts"
os.makedirs("risk_layouts/", exist_ok=True)

# Get a list of all .tif files in the folder
tif_files = glob(os.path.join(folder_path, "*.tif"))
print(tif_files)

layout_list = []

# Open each .tif file
for tif_file in tif_files:
    id = tif_file.split('/')[2].split('_E')[0]
    print(f"Processing {id}...")

    output_path = os.path.join("risk_layouts", f"whpi2023_cnt_{id}.tif")
    try:
        with rasterio.open(tif_file) as src1:
            # print the resolution of the raster in meters
            print(src1.res)
            out_image, out_transform = mask(src1, geo_json, crop=True)
            out_meta = src1.meta.copy()
            out_meta.update({
                "driver": "GTiff",
                "height": out_image.shape[1],
                "width": out_image.shape[2],
                "transform": out_transform
            })

            # Save cropped image
            with rasterio.open(output_path, "w", **out_meta) as dest:
                dest.write(out_image)
    except (ValueError, WindowError) as e:
        print(f"Error masking raster: {e}")
        
    print(f"Saved cropped intersection as {output_path}")
# Out:
# ['../../sim2real_layouts/0025_02019_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0049_01289_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0065_03061_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0089_00984_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0057_03186_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0255_02103_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0023_00995_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0012_02094_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0020_00970_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0067_03550_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0111_03612_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0092_03189_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0016_03070_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0068_04211_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0246_00984_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0047_05424_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0098_01784_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0083_02892_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0324_02925_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0258_02858_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0095_01726_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0093_01748_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0094_01688_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0063_02387_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0249_02843_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0105_03054_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0004_01191_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0066_03773_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0058_03866_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0013_01466_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0041_02386_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0060_03010_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0270_02277_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0021_01232_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0257_02175_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0253_03246_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0113_03495_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0103_01810_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0259_02663_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0024_02655_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0254_02361_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0251_02843_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0090_00987_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0248_01962_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0100_02449_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0064_02717_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0114_02292_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0250_02864_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0037_01578_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0104_02422_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0106_02165_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0344_03155_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0242_02940_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0244_03110_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0252_02927_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0082_03155_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0048_01141_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0243_02722_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0084_02609_Existing_Vegetation_Cover.tif', '../../sim2real_layouts/0069_03539_Existing_Ve ...
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Error masking raster: Input shapes do not overlap raster.
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Error masking raster: Input shapes do not overlap raster.
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Error masking raster: Input shapes do not overlap raster.
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Error masking raster: Input shapes do not overlap raster.
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Error masking raster: Input shapes do not overlap raster.
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Error masking raster: Input shapes do not overlap raster.
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Error masking raster: Input shapes do not overlap raster.
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Error masking raster: Input shapes do not overlap raster.
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif
# Processing sim2real_layouts...
# (30.0, 30.0)
# Saved cropped intersection as risk_layouts/whpi2023_cnt_sim2real_layouts.tif

# %%
tif_files = glob(os.path.join("risk_layouts", "*.tif"))
for tif_file in tif_files:
    # print(f"Processing {tif_file}...")
    id = "_".join(tif_file.split('/')[1].split('_E')[0].split('_')[-3:]).split('.')[0]
    print(id)
    with rasterio.open(tif_file) as src:
        wfpi_data = src.read(1)
        print(wfpi_data.shape)
        # print resolution of the raster in meters
        print(src.res)
    plt.imshow(wfpi_data, cmap='hot', vmin=0, vmax=500)
    plt.colorbar(label="WFPI Value")
    plt.title("Wind-enhanced Fire Potential Index (WFPI)")
    plt.show()
    # print the corresponding layout png
    layout_png_file = os.path.join("../WideDataset", f"{id}/satellite_image.png")
    layout_png = plt.imread(layout_png_file)
    plt.imshow(layout_png)
    plt.show()
# Out:
# cnt_sim2real_layouts
# (1046, 846)
# (30.0, 30.0)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 17
#      15 # print the corresponding layout png
#      16 layout_png_file = os.path.join("../WideDataset", f"{id}/satellite_image.png")
# ---> 17 layout_png = plt.imread(layout_png_file)
#      18 plt.imshow(layout_png)
#      19 plt.show()
#
# File /opt/anaconda3/envs/wildfire/lib/python3.11/site-packages/matplotlib/pyplot.py:2613, in imread(fname, format)
#    2609 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2610 def imread(
#    2611         fname: str | pathlib.Path | BinaryIO, format: str | None = None
#    2612 ) -> np.ndarray:
# -> 2613     return matplotlib.image.imread(fname, format)
#
# File /opt/anaconda3/envs/wildfire/lib/python3.11/site-packages/matplotlib/image.py:1502, in imread(fname, format)
#    1495 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1496     # Pillow doesn't handle URLs directly.
#    1497     raise ValueError(
#    1498         "Please open the URL for reading and pass the "
#    1499         "result to Pillow, e.g. with "
#    1500         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1501         )
# -> 1502 with img_open(fname) as image:
#    1503     return (_pil_png_to_float_array(image)
#    1504             if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#    1505             pil_to_array(image))
#
# File /opt/anaconda3/envs/wildfire/lib/python3.11/site-packages/PIL/ImageFile.py:132, in ImageFile.__init__(self, fp, filename)
#     128 self.decodermaxblock = MAXBLOCK
#     130 if is_path(fp):
#     131     # filename
# --> 132     self.fp = open(fp, "rb")
#     133     self.filename = os.fspath(fp)
#     134     self._exclusive_fp = True
#
# FileNotFoundError: [Errno 2] No such file or directory: '../WideDataset/cnt_sim2real_layouts/satellite_image.png'

# %%
def convert_tif_to_npy(input_folder, output_folder):
    """
    Convert all .tif or .tiff files in a folder to .npy format.

    Args:
        input_folder (str): Path to the directory containing .tif/.tiff files.
        output_folder (str): Path to the directory where .npy files will be saved.
        max_files (int, optional): Maximum number of .tif files to process. If None, process all files.

    Yields:
        str: Path to each .npy file created.
    """
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for file in os.listdir(input_folder):
        if file.lower().endswith('.tif') or file.lower().endswith('.tiff'):
            tif_path = os.path.join(input_folder, file)
            with rasterio.open(tif_path) as src:
                data = src.read(1)  # Read the first band
                # duplicate the data to go from shape (N,M) to shape (100,N,M)
                data = np.tile(data, (1, 1, 1))
                print(data.shape)

            npy_filename = os.path.splitext(file)[0] + '.npy'
            np.save(os.path.join(output_folder, npy_filename), data)
            print(f"Converted {file} to {npy_filename}")

# %%
# convert tif files to npy files
convert_tif_to_npy("./risk_layouts", "./risk_layouts_npy")
# Out:
# (1, 919, 1041)
# Converted whpi2023_cnt_0062_03187.tif to whpi2023_cnt_0062_03187.npy
# (1, 783, 770)
# Converted whpi2023_cnt_0243_02722.tif to whpi2023_cnt_0243_02722.npy
# (1, 819, 930)
# Converted whpi2023_cnt_0057_03186.tif to whpi2023_cnt_0057_03186.npy
# (1, 551, 607)
# Converted whpi2023_cnt_0041_02386.tif to whpi2023_cnt_0041_02386.npy
# (1, 770, 819)
# Converted whpi2023_cnt_0247_03453.tif to whpi2023_cnt_0247_03453.npy
# (1, 655, 681)
# Converted whpi2023_cnt_0259_02663.tif to whpi2023_cnt_0259_02663.npy
# (1, 1046, 846)
# Converted whpi2023_cnt_0103_01810.tif to whpi2023_cnt_0103_01810.npy
# (1, 945, 1163)
# Converted whpi2023_cnt_0098_01784.tif to whpi2023_cnt_0098_01784.npy
# (1, 815, 821)
# Converted whpi2023_cnt_0064_02717.tif to whpi2023_cnt_0064_02717.npy
# (1, 256, 506)
# Converted whpi2023_cnt_0344_03155.tif to whpi2023_cnt_0344_03155.npy
# (1, 1046, 846)
# Converted whpi2023_cnt_0102_01733.tif to whpi2023_cnt_0102_01733.npy
# (1, 1323, 1484)
# Converted whpi2023_cnt_0048_01141.tif to whpi2023_cnt_0048_01141.npy
# (1, 700, 720)
# Converted whpi2023_cnt_0252_02927.tif to whpi2023_cnt_0252_02927.npy
# (1, 1050, 1098)
# Converted whpi2023_cnt_0244_03110.tif to whpi2023_cnt_0244_03110.npy
# (1, 791, 845)
# Converted whpi2023_cnt_0059_02804.tif to whpi2023_cnt_0059_02804.npy
# (1, 984, 1003)
# Converted whpi2023_cnt_0060_03010.tif to whpi2023_cnt_0060_03010.npy
# (1, 523, 612)
# Converted whpi2023_cnt_0016_03070.tif to whpi2023_cnt_0016_03070.npy
# (1, 902, 1049)
# Converted whpi2023_cnt_0260_03391.tif to whpi2023_cnt_0260_03391.npy
# (1, 817, 806)
# Converted whpi2023_cnt_0246_00984.tif to whpi2023_cnt_0246_00984.npy
# (1, 729, 807)
# Converted whpi2023_cnt_0084_02609.tif to whpi2023_cnt_0084_02609.npy
# (1, 821, 837)
# Converted whpi2023_cnt_0066_03773.tif to whpi2023_cnt_0066_03773.npy
# (1, 565, 531)
# Converted whpi2023_cnt_0024_02655.tif to whpi2023_cnt_0024_02655.npy
# (1, 731, 715)
# Converted whpi2023_cnt_0250_02864.tif to whpi2023_cnt_0250_02864.npy
# (1, 643, 648)
# Converted whpi2023_cnt_0105_03054.tif to whpi2023_cnt_0105_03054.npy
# (1, 882, 875)
# Converted whpi2023_cnt_0068_04211.tif to whpi2023_cnt_0068_04211.npy
# (1, 977, 1102)
# Converted whpi2023_cnt_0095_01726.tif to whpi2023_cnt_0095_01726.npy
# (1, 1317, 1124)
# Converted whpi2023_cnt_0021_01232.tif to whpi2023_cnt_0021_01232.npy
# (1, 574, 502)
# Converted whpi2023_cnt_0025_02019.tif to whpi2023_cnt_0025_02019.npy
# (1, 962, 1043)
# Converted whpi2023_cnt_0262_03319.tif to whpi2023_cnt_0262_03319.npy
# (1, 711, 741)
# Converted whpi2023_cnt_0249_02843.tif to whpi2023_cnt_0249_02843.npy
# (1, 774, 838)
# Converted whpi2023_cnt_0069_03539.tif to whpi2023_cnt_0069_03539.npy
# (1, 859, 982)
# Converted whpi2023_cnt_0081_03471.tif to whpi2023_cnt_0081_03471.npy
# (1, 534, 539)
# Converted whpi2023_cnt_0106_02165.tif to whpi2023_cnt_0106_02165.npy
# (1, 816, 776)
# Converted whpi2023_cnt_0012_02094.tif to whpi2023_cnt_0012_02094.npy
# (1, 568, 579)
# Converted whpi2023_cnt_0023_00995.tif to whpi2023_cnt_0023_00995.npy
# (1, 1044, 1131)
# Converted whpi2023_cnt_0061_03726.tif to whpi2023_cnt_0061_03726.npy
# (1, 816, 776)
# Converted whpi2023_cnt_0013_01466.tif to whpi2023_cnt_0013_01466.npy
# (1, 395, 547)
# Converted whpi2023_cnt_0092_03189.tif to whpi2023_cnt_0092_03189.npy
# (1, 968, 1104)
# Converted whpi2023_cnt_0083_02892.tif to whpi2023_cnt_0083_02892.npy
# (1, 931, 583)
# Converted whpi2023_cnt_0089_00984.tif to whpi2023_cnt_0089_00984.npy
# (1, 1317, 1124)
# Converted whpi2023_cnt_0020_00970.tif to whpi2023_cnt_0020_00970.npy
# (1, 1009, 931)
# Converted whpi2023_cnt_0090_00987.tif to whpi2023_cnt_0090_00987.npy
# (1, 1064, 1125)
# Converted whpi2023_cnt_0063_02387.tif to whpi2023_cnt_0063_02387.npy
# (1, 677, 771)
# Converted whpi2023_cnt_0251_02843.tif to whpi2023_cnt_0251_02843.npy
# (1, 772, 819)
# Converted whpi2023_cnt_0065_03061.tif to whpi2023_cnt_0065_03061.npy
# (1, 1037, 974)
# Converted whpi2023_cnt_0245_03988.tif to whpi2023_cnt_0245_03988.npy
# (1, 673, 727)
# Converted whpi2023_cnt_0324_02925.tif to whpi2023_cnt_0324_02925.npy
# (1, 859, 907)
# Converted whpi2023_cnt_0082_03155.tif to whpi2023_cnt_0082_03155.npy
# (1, 1734, 1489)
# Converted whpi2023_cnt_0047_05424.tif to whpi2023_cnt_0047_05424.npy
# (1, 557, 583)
# Converted whpi2023_cnt_0104_02422.tif to whpi2023_cnt_0104_02422.npy
# (1, 977, 1102)
# Converted whpi2023_cnt_0094_01688.tif to whpi2023_cnt_0094_01688.npy
# (1, 424, 771)
# Converted whpi2023_cnt_0019_01316.tif to whpi2023_cnt_0019_01316.npy
# (1, 1066, 1096)
# Converted whpi2023_cnt_0058_03866.tif to whpi2023_cnt_0058_03866.npy
# (1, 449, 618)
# Converted whpi2023_cnt_0270_02277.tif to whpi2023_cnt_0270_02277.npy
# (1, 417, 770)
# Converted whpi2023_cnt_0004_01191.tif to whpi2023_cnt_0004_01191.npy
# (1, 541, 684)
# Converted whpi2023_cnt_0037_01578.tif to whpi2023_cnt_0037_01578.npy
# (1, 806, 803)
# Converted whpi2023_cnt_0067_03550.tif to whpi2023_cnt_0067_03550.npy
# (1, 945, 1163)
# Converted whpi2023_cnt_0100_02449.tif to whpi2023_cnt_0100_02449.npy
# (1, 1048, 1490)
# Converted whpi2023_cnt_0049_01289.tif to whpi2023_cnt_0049_01289.npy
# (1, 748, 780)
# Converted whpi2023_cnt_0248_01962.tif to whpi2023_cnt_0248_01962.npy
# (1, 953, 932)
# Converted whpi2023_cnt_0242_02940.tif to whpi2023_cnt_0242_02940.npy
# (1, 948, 923)
# Converted whpi2023_cnt_0261_02900.tif to whpi2023_cnt_0261_02900.npy
# (1, 599, 573)
# Converted whpi2023_cnt_0111_03612.tif to whpi2023_cnt_0111_03612.npy
# (1, 977, 1102)
# Converted whpi2023_cnt_0093_01748.tif to whpi2023_cnt_0093_01748.npy

# %%
# move the .npy files from the risk_layouts folder to the appropriate folder
import shutil
import os
from glob import glob

# Path to the folder containing .tif files
folder_path = "../sim2real_layouts"

# Get a list of all .tif files in the folder
tif_files = glob(os.path.join(folder_path, "*.tif"))

layout_list = []
missing_layouts = []

# Open each .tif file
for tif_file in tif_files:
    id = tif_file.split('/')[2].split('_E')[0]
    print(id)
    rskfile_path = os.path.join("risk_layouts_npy", f"whpi2023_cnt_{id}.npy")
    if os.path.exists(rskfile_path):
        #print("copying", rskfile_path, "to", "./WideDataset", f"{id}/static_risk.npy")
        try:
            shutil.copy(rskfile_path, os.path.join("./WideDataset", f"{id}/static_risk.npy"))
        except Exception as e:
            print(f"Error copying {rskfile_path} : {e}")
    else:
        missing_layouts.append(id)
print(len(missing_layouts), "layouts skipped, copied", len(tif_files) - len(missing_layouts), "layouts")
# Out:
# 0025_02019
# Error copying risk_layouts_npy/whpi2023_cnt_0025_02019.npy : [Errno 2] No such file or directory: './WideDataset/0025_02019/static_risk.npy'
# 0049_01289
# Error copying risk_layouts_npy/whpi2023_cnt_0049_01289.npy : [Errno 2] No such file or directory: './WideDataset/0049_01289/static_risk.npy'
# 0065_03061
# Error copying risk_layouts_npy/whpi2023_cnt_0065_03061.npy : [Errno 2] No such file or directory: './WideDataset/0065_03061/static_risk.npy'
# 0089_00984
# Error copying risk_layouts_npy/whpi2023_cnt_0089_00984.npy : [Errno 2] No such file or directory: './WideDataset/0089_00984/static_risk.npy'
# 0057_03186
# Error copying risk_layouts_npy/whpi2023_cnt_0057_03186.npy : [Errno 2] No such file or directory: './WideDataset/0057_03186/static_risk.npy'
# 0255_02103
# 0023_00995
# Error copying risk_layouts_npy/whpi2023_cnt_0023_00995.npy : [Errno 2] No such file or directory: './WideDataset/0023_00995/static_risk.npy'
# 0012_02094
# Error copying risk_layouts_npy/whpi2023_cnt_0012_02094.npy : [Errno 2] No such file or directory: './WideDataset/0012_02094/static_risk.npy'
# 0020_00970
# Error copying risk_layouts_npy/whpi2023_cnt_0020_00970.npy : [Errno 2] No such file or directory: './WideDataset/0020_00970/static_risk.npy'
# 0067_03550
# Error copying risk_layouts_npy/whpi2023_cnt_0067_03550.npy : [Errno 2] No such file or directory: './WideDataset/0067_03550/static_risk.npy'
# 0111_03612
# Error copying risk_layouts_npy/whpi2023_cnt_0111_03612.npy : [Errno 2] No such file or directory: './WideDataset/0111_03612/static_risk.npy'
# 0092_03189
# Error copying risk_layouts_npy/whpi2023_cnt_0092_03189.npy : [Errno 2] No such file or directory: './WideDataset/0092_03189/static_risk.npy'
# 0016_03070
# Error copying risk_layouts_npy/whpi2023_cnt_0016_03070.npy : [Errno 2] No such file or directory: './WideDataset/0016_03070/static_risk.npy'
# 0068_04211
# Error copying risk_layouts_npy/whpi2023_cnt_0068_04211.npy : [Errno 2] No such file or directory: './WideDataset/0068_04211/static_risk.npy'
# 0246_00984
# Error copying risk_layouts_npy/whpi2023_cnt_0246_00984.npy : [Errno 2] No such file or directory: './WideDataset/0246_00984/static_risk.npy'
# 0047_05424
# Error copying risk_layouts_npy/whpi2023_cnt_0047_05424.npy : [Errno 2] No such file or directory: './WideDataset/0047_05424/static_risk.npy'
# 0098_01784
# Error copying risk_layouts_npy/whpi2023_cnt_0098_01784.npy : [Errno 2] No such file or directory: './WideDataset/0098_01784/static_risk.npy'
# 0083_02892
# Error copying risk_layouts_npy/whpi2023_cnt_0083_02892.npy : [Errno 2] No such file or directory: './WideDataset/0083_02892/static_risk.npy'
# 0324_02925
# Error copying risk_layouts_npy/whpi2023_cnt_0324_02925.npy : [Errno 2] No such file or directory: './WideDataset/0324_02925/static_risk.npy'
# 0258_02858
# 0095_01726
# Error copying risk_layouts_npy/whpi2023_cnt_0095_01726.npy : [Errno 2] No such file or directory: './WideDataset/0095_01726/static_risk.npy'
# 0093_01748
# Error copying risk_layouts_npy/whpi2023_cnt_0093_01748.npy : [Errno 2] No such file or directory: './WideDataset/0093_01748/static_risk.npy'
# 0094_01688
# Error copying risk_layouts_npy/whpi2023_cnt_0094_01688.npy : [Errno 2] No such file or directory: './WideDataset/0094_01688/static_risk.npy'
# 0063_02387
# Error copying risk_layouts_npy/whpi2023_cnt_0063_02387.npy : [Errno 2] No such file or directory: './WideDataset/0063_02387/static_risk.npy'
# 0249_02843
# Error copying risk_layouts_npy/whpi2023_cnt_0249_02843.npy : [Errno 2] No such file or directory: './WideDataset/0249_02843/static_risk.npy'
# 0105_03054
# Error copying risk_layouts_npy/whpi2023_cnt_0105_03054.npy : [Errno 2] No such file or directory: './WideDataset/0105_03054/static_risk.npy'
# 0004_01191
# Error copying risk_layouts_npy/whpi2023_cnt_0004_01191.npy : [Errno 2] No such file or directory: './WideDataset/0004_01191/static_risk.npy'
# 0066_03773
# Error copying risk_layouts_npy/whpi2023_cnt_0066_03773.npy : [Errno 2] No such file or directory: './WideDataset/0066_03773/static_risk.npy'
# 0058_03866
# Error copying risk_layouts_npy/whpi2023_cnt_0058_03866.npy : [Errno 2] No such file or directory: './WideDataset/0058_03866/static_risk.npy'
# 0013_01466
# Error copying risk_layouts_npy/whpi2023_cnt_0013_01466.npy : [Errno 2] No such file or directory: './WideDataset/0013_01466/static_risk.npy'
# 0041_02386
# Error copying risk_layouts_npy/whpi2023_cnt_0041_02386.npy : [Errno 2] No such file or directory: './WideDataset/0041_02386/static_risk.npy'
# 0060_03010
# Error copying risk_layouts_npy/whpi2023_cnt_0060_03010.npy : [Errno 2] No such file or directory: './WideDataset/0060_03010/static_risk.npy'
# 0270_02277
# Error copying risk_layouts_npy/whpi2023_cnt_0270_02277.npy : [Errno 2] No such file or directory: './WideDataset/0270_02277/static_risk.npy'
# 0021_01232
# Error copying risk_layouts_npy/whpi2023_cnt_0021_01232.npy : [Errno 2] No such file or directory: './WideDataset/0021_01232/static_risk.npy'
# 0257_02175
# 0253_03246
# 0113_03495
# 0103_01810
# Error copying risk_layouts_npy/whpi2023_cnt_0103_01810.npy : [Errno 2] No such file or directory: './WideDataset/0103_01810/static_risk.npy'
# 0259_02663
# Error copying risk_layouts_npy/whpi2023_cnt_0259_02663.npy : [Errno 2] No such file or directory: './WideDataset/0259_02663/static_risk.npy'
# 0024_02655
# Error copying risk_layouts_npy/whpi2023_cnt_0024_02655.npy : [Errno 2] No such file or directory: './WideDataset/0024_02655/static_risk.npy'
# 0254_02361
# 0251_02843
# Error copying risk_layouts_npy/whpi2023_cnt_0251_02843.npy : [Errno 2] No such file or directory: './WideDataset/0251_02843/static_risk.npy'
# 0090_00987
# Error copying risk_layouts_npy/whpi2023_cnt_0090_00987.npy : [Errno 2] No such file or directory: './WideDataset/0090_00987/static_risk.npy'
# 0248_01962
# Error copying risk_layouts_npy/whpi2023_cnt_0248_01962.npy : [Errno 2] No such file or directory: './WideDataset/0248_01962/static_risk.npy'
# 0100_02449
# Error copying risk_layouts_npy/whpi2023_cnt_0100_02449.npy : [Errno 2] No such file or directory: './WideDataset/0100_02449/static_risk.npy'
# 0064_02717
# Error copying risk_layouts_npy/whpi2023_cnt_0064_02717.npy : [Errno 2] No such file or directory: './WideDataset/0064_02717/static_risk.npy'
# 0114_02292
# 0250_02864
# Error copying risk_layouts_npy/whpi2023_cnt_0250_02864.npy : [Errno 2] No such file or directory: './WideDataset/0250_02864/static_risk.npy'
# 0037_01578
# Error copying risk_layouts_npy/whpi2023_cnt_0037_01578.npy : [Errno 2] No such file or directory: './WideDataset/0037_01578/static_risk.npy'
# 0104_02422
# Error copying risk_layouts_npy/whpi2023_cnt_0104_02422.npy : [Errno 2] No such file or directory: './WideDataset/0104_02422/static_risk.npy'
# 0106_02165
# Error copying risk_layouts_npy/whpi2023_cnt_0106_02165.npy : [Errno 2] No such file or directory: './WideDataset/0106_02165/static_risk.npy'
# 0344_03155
# Error copying risk_layouts_npy/whpi2023_cnt_0344_03155.npy : [Errno 2] No such file or directory: './WideDataset/0344_03155/static_risk.npy'
# 0242_02940
# Error copying risk_layouts_npy/whpi2023_cnt_0242_02940.npy : [Errno 2] No such file or directory: './WideDataset/0242_02940/static_risk.npy'
# 0244_03110
# Error copying risk_layouts_npy/whpi2023_cnt_0244_03110.npy : [Errno 2] No such file or directory: './WideDataset/0244_03110/static_risk.npy'
# 0252_02927
# Error copying risk_layouts_npy/whpi2023_cnt_0252_02927.npy : [Errno 2] No such file or directory: './WideDataset/0252_02927/static_risk.npy'
# 0082_03155
# Error copying risk_layouts_npy/whpi2023_cnt_0082_03155.npy : [Errno 2] No such file or directory: './WideDataset/0082_03155/static_risk.npy'
# 0048_01141
# Error copying risk_layouts_npy/whpi2023_cnt_0048_01141.npy : [Errno 2] No such file or directory: './WideDataset/0048_01141/static_risk.npy'
# 0243_02722
# Error copying risk_layouts_npy/whpi2023_cnt_0243_02722.npy : [Errno 2] No such file or directory: './WideDataset/0243_02722/static_risk.npy'
# 0084_02609
# Error copying risk_layouts_npy/whpi2023_cnt_0084_02609.npy : [Errno 2] No such file or directory: './WideDataset/0084_02609/static_risk.npy'
# 0069_03539
# Error copying risk_layouts_npy/whpi2023_cnt_0069_03539.npy : [Errno 2] No such file or directory: './WideDataset/0069_03539/static_risk.npy'
# 0256_02752
# 0260_03391
# Error copying risk_layouts_npy/whpi2023_cnt_0260_03391.npy : [Errno 2] No such file or directory: './WideDataset/0260_03391/static_risk.npy'
# 0262_03319
# Error copying risk_layouts_npy/whpi2023_cnt_0262_03319.npy : [Errno 2] No such file or directory: './WideDataset/0262_03319/static_risk.npy'
# 0081_03471
# Error copying risk_layouts_npy/whpi2023_cnt_0081_03471.npy : [Errno 2] No such file or directory: './WideDataset/0081_03471/static_risk.npy'
# 0062_03187
# Error copying risk_layouts_npy/whpi2023_cnt_0062_03187.npy : [Errno 2] No such file or directory: './WideDataset/0062_03187/static_risk.npy'
# 0019_01316
# Error copying risk_layouts_npy/whpi2023_cnt_0019_01316.npy : [Errno 2] No such file or directory: './WideDataset/0019_01316/static_risk.npy'
# 0247_03453
# Error copying risk_layouts_npy/whpi2023_cnt_0247_03453.npy : [Errno 2] No such file or directory: './WideDataset/0247_03453/static_risk.npy'
# 0261_02900
# Error copying risk_layouts_npy/whpi2023_cnt_0261_02900.npy : [Errno 2] No such file or directory: './WideDataset/0261_02900/static_risk.npy'
# 0061_03726
# Error copying risk_layouts_npy/whpi2023_cnt_0061_03726.npy : [Errno 2] No such file or directory: './WideDataset/0061_03726/static_risk.npy'
# 0245_03988
# Error copying risk_layouts_npy/whpi2023_cnt_0245_03988.npy : [Errno 2] No such file or directory: './WideDataset/0245_03988/static_risk.npy'
# 0059_02804
# Error copying risk_layouts_npy/whpi2023_cnt_0059_02804.npy : [Errno 2] No such file or directory: './WideDataset/0059_02804/static_risk.npy'
# 0102_01733
# Error copying risk_layouts_npy/whpi2023_cnt_0102_01733.npy : [Errno 2] No such file or directory: './WideDataset/0102_01733/static_risk.npy'
# 8 layouts skipped, copied 64 layouts

# %%
print(missing_layouts)
# Out:
# ['0255_02103', '0258_02858', '0257_02175', '0253_03246', '0113_03495', '0254_02361', '0114_02292', '0256_02752']
